# %%
# import libraries 
import pandas as pd # Import Pandas for data manipulation using dataframes
import matplotlib.pyplot as plt # Import matplotlib for data visualisation

# %%
Djisktra_vs_Bellman = pd.read_csv('result.csv')
Djisktra_vs_Bellman.sort_values('Number of nodes', inplace=True)
Djisktra_vs_Bellman
# Out:
#     Number of nodes  Number of edges  Bellman-Ford time  Dijkstra time  \
# 0                10               20           0.000999       0.000000
# 7                20               40           0.001000       0.000000
# 8                30               60           0.001000       0.001012
# 9                35               70           0.001000       0.001000
# 10               40               80           0.001000       0.000000
# 1                50              100           0.001007       0.000000
# 11               60              120           0.001124       0.001403
# 12               70              140           0.002001       0.001000
# 13               80              160           0.001999       0.001000
# 14               90              180           0.001990       0.000000
# 2               100              200           0.003000       0.000000
# 15              150              300           0.004869       0.002002
# 3               200              400           0.003995       0.002000
# 16              250              500           0.005016       0.003985
# 4               300              600           0.006002       0.005999
# 17              350              700           0.006000       0.004022
# 18              450              900           0.011004       0.004997
# 5               500             1000           0.011002       0.004999
# 19              600             1200           0.012001       0.000000
# 20              700             1400           0.017001       0.006000
# 21              800             1600           0.017988       0.010001
# 22              900             1800           0.017009       0.007003
# 6              1000             2000           0.120013       0.013001
#
#                           Packet path  Packet arrival time (seconds)
# 0                        [0, 5, 1, 9]                              3
# 7                       [0, 5, 2, 19]                              3
# 8                             [0, 29]                              1
# 9                      [0, 3, 20, 34]                              3
# 10                    [0, 15, 28, 39]                              3
# 1                      [0, 4, 22, 49]                              3
# 11                 [0, 28, 29, 8, 59]                              4
# 12                [0, 47, 64, 29, 69]                              4
# 13                [0, 64, 58, 29, 79]                              4
# 14                        [0, 79, 89]                              2
# 2                         [0, 48, 99]                              2
# 15       [0, 82, 43, 11, 13, 34, 149]                              6
# 3               [0, 33, 65, 132, 199]                              4
# 16          [0, 83, 34, 40, 222, 249]                              5
# 4           [0, 8, 186, 222, 64, 299]                              5
# 17               [0, 121, 5, 70, 349]                              4
# 18    [0, 380, 203, 104, 83, 93, 449]                              6
# 5        [0, 299, 104, 267, 490, 499]                              5
# 19                      [0, 222, 599]                              2
# 20              [0, 5, 264, 354, 699]                              4
# 21    [0, 169, 451, 413, 9, 577, 799]                              6
# 22         [0, 258, 151, 3, 826, 899]                              5
# 6   [0, 920, 318, 238, 977, 790, 999]                              6

# %%
plt.figure(figsize=(10,10))
plt.plot(Djisktra_vs_Bellman['Number of nodes'], Djisktra_vs_Bellman['Bellman-Ford time'], label='Bellman-Ford time')
plt.plot(Djisktra_vs_Bellman['Number of nodes'], Djisktra_vs_Bellman['Dijkstra time'], label='Dijkstra time')
plt.xlabel('Number of nodes')
plt.legend()
plt.show()
