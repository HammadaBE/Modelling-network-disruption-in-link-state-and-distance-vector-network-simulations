# %%
# import libraries 
import pandas as pd # Import Pandas for data manipulation using dataframes
import matplotlib.pyplot as plt # Import matplotlib for data visualisation

# %%
Djisktra_vs_Bellman = pd.read_csv('result.csv')
Djisktra_vs_Bellman.sort_values('Number of nodes', inplace=True)
Djisktra_vs_Bellman
# Out:
#     Number of nodes  Number of edges  Bellman-Ford time  Dijkstra time  \
# 0                10               20           0.007978       0.000000
# 1                20               40           0.000000       0.000000
# 2                30               60           0.000000       0.000000
# 3                40               80           0.007995       0.000000
# 4                50              100           0.000000       0.000000
# 5                60              120           0.007992       0.000000
# 6                70              140           0.000000       0.000000
# 7                80              160           0.000000       0.008002
# 8                80              160           0.000000       0.000000
# 9                90              180           0.000000       0.000000
# 10              100              200           0.000000       0.008002
# 11              110              220           0.008007       0.000000
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(Djisktra_vs_Bellman['Number of nodes'], Djisktra_vs_Bellman['Bellman-Ford time'], label='Bellman-Ford time')
plt.plot(Djisktra_vs_Bellman['Number of nodes'], Djisktra_vs_Bellman['Dijkstra time'], label='Dijkstra time')
#plt.plot(Djisktra_vs_Bellman['Number of nodes'], Djisktra_vs_Bellman['Packet arrival time'], label='Packet arrival time')
plt.plot(Djisktra_vs_Bellman['Number of nodes'], Djisktra_vs_Bellman['Distance Vector Latency'], label='Distance Vector Latency')
plt.plot(Djisktra_vs_Bellman['Number of nodes'], Djisktra_vs_Bellman['Link-State latency'], label='Link-State latency')
plt.xlabel('Number of nodes')
plt.legend()
plt.show()

# %%
LinkState_vs_DistanceVector = pd.read_csv('results.csv')
LinkState_vs_DistanceVector.sort_values('Number of Nodes', inplace=True)
LinkState_vs_DistanceVector
# Out:
#    Number of Nodes  Number of Edges  Distance Vector Latency  \
# 0              250              500                 0.003007
# 1              500             1000                 0.002001
#
#    Distance Vector Convergence  Link-State Latency  Link-State Convergence
# 0                          NaN            0.002003                     NaN
# 1                          NaN            0.002002                     NaN
